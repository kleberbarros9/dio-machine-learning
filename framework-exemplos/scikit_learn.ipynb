# %%
from sklearn.datasets import make_regression
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

# %%
# gerando os dados
X, y = make_regression(n_samples=200, n_features=1, noise=30)

# criando o modelo de regressão linear
model = LinearRegression()

# treinando o modelo
model.fit(X, y)

# vizualizando os dados e linha da regressão
plt.scatter(X, y, label='Dados originais')
plt.plot(X, model.predict(X), color='red', label='Regressão linear')
plt.title('Regressão Linear com Scikit-Learn')
plt.xlabel('Variavel X (preditor)')
plt.ylabel('Variavel y (targer)')
plt.legend()
plt.show()
