# %%
# !wget https://pns2019.github.io/images/Lenna.png
# Out:
# --2024-12-10 14:22:25--  https://pns2019.github.io/images/Lenna.png
# Resolving pns2019.github.io (pns2019.github.io)... 185.199.108.153, 185.199.109.153, 185.199.110.153, ...
# Connecting to pns2019.github.io (pns2019.github.io)|185.199.108.153|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 473831 (463K) [image/png]
# Saving to: ‘Lenna.png’
#
# Lenna.png           100%[===================>] 462.73K  --.-KB/s    in 0.05s
#
# 2024-12-10 14:22:25 (9.70 MB/s) - ‘Lenna.png’ saved [473831/473831]

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
# lendo a imagem
img = cv2.imread('Lenna.png')

# preparando um filtro de média 11x11
kernel = np.ones((11,11),np.float32)/121

# aplicando o filtro
dst = cv2.filter2D(img,-1,kernel)

# mudando a imagem do espaço BGR para o espaço RGB
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
dst = cv2.cvtColor(dst, cv2.COLOR_BGR2RGB)

# mostrando a imagem original e a imagem filtrada
plt.subplot(121),plt.imshow(img),plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(dst),plt.title('Averaging')
plt.xticks([]), plt.yticks([])
plt.show()

# %%
# lendo a imagem
img = cv2.imread('Lenna.png', 0)

# realizando filtragem laplaciana
laplacian = cv2.Laplacian(img,cv2.CV_64F)

# encontrando borda vertical
sobelx = cv2.Sobel(img,cv2.CV_64F,1,0,ksize=3)

# encontrando borda horizontal
sobely = cv2.Sobel(img,cv2.CV_64F,0,1,ksize=3)

plt.subplot(2,2,1),plt.imshow(img,cmap = 'gray')
plt.title('Original'), plt.xticks([]), plt.yticks([])
plt.subplot(2,2,2),plt.imshow(laplacian,cmap = 'gray')
plt.title('Laplacian'), plt.xticks([]), plt.yticks([])
plt.subplot(2,2,3),plt.imshow(sobelx,cmap = 'gray')
plt.title('Sobel X'), plt.xticks([]), plt.yticks([])
plt.subplot(2,2,4),plt.imshow(sobely,cmap = 'gray')
plt.title('Sobel Y'), plt.xticks([]), plt.yticks([])
plt.show()
